# %%
import matplotlib as mtl
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# 基础绘图，指定线条样式及颜色
plt.plot(['Jan', 'Fre', 'Mat', 'Apr', 'May', 'Jun'], [0, 2, 4, 6, 8, 10], '-', color='r')
plt.xlabel('Month', fontsize=14)
plt.ylabel('Value', fontsize=14)
# Out:
# Text(0, 0.5, 'Value')

# %%
# 使用子图绘制安斯库姆四重奏
# nmi n行m列第i个图
plt.subplot(221)
plt.plot([10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0], 
             [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68], '.', color='r')

plt.subplot(222)
plt.plot([10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0], 
             [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74], '.', color='b')

plt.subplot(223)
plt.plot([10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0], 
             [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73], '.', color='g')

plt.subplot(224)
plt.plot([8.0, 8.0, 8.0, 8.0, 8.0, 8.0, 8.0, 19.0, 8.0, 8.0, 8.0], 
             [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89], '.', color='y')

# %%
# 风格设置
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
import numpy as np
x = np.linspace(-10, 10)
# 设置风格
plt.style.use('bmh')
plt.plot(x, np.sin(x))
