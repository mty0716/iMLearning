# %%
# %run poetry_gen.py --mode train
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x000001695DEB5FD0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# INFO:tensorflow:Restoring parameters from None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: expected bytes, NoneType found
#
# During handling of the above exception, another exception occurred:
#
# SystemError                               Traceback (most recent call last)
# D:\Installation\WampServer\www\PyProjects\iJupyter\NLP\03.基于RNN语言模型的文本生成\poetry_gen.py in <module>()
#     263
#     264 if __name__ == '__main__':
# --> 265     main()
#
# D:\Installation\WampServer\www\PyProjects\iJupyter\NLP\03.基于RNN语言模型的文本生成\poetry_gen.py in main()
#     257         data = Data()
#     258         model = Model(data=data, infer=infer)
# --> 259         print(train(data, model))
# ...

# %%
# %run poetry_gen.py --mode sample --head 明月别枝惊鹊
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x000001695E4D6F28>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# INFO:tensorflow:Restoring parameters from None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: expected bytes, NoneType found
#
# During handling of the above exception, another exception occurred:
#
# SystemError                               Traceback (most recent call last)
# D:\Installation\WampServer\www\PyProjects\iJupyter\NLP\03.基于RNN语言模型的文本生成\poetry_gen.py in <module>()
#     263
#     264 if __name__ == '__main__':
# --> 265     main()
#
# D:\Installation\WampServer\www\PyProjects\iJupyter\NLP\03.基于RNN语言模型的文本生成\poetry_gen.py in main()
#     252         data = Data()
#     253         model = Model(data=data, infer=infer)
# ...
