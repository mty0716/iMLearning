# %%
# %run train.py --cell_type "lstm"
# Out:
# /root/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Parameters:
# ALLOW_SOFT_PLACEMENT = <absl.flags._flag.BooleanFlag object at 0x7fbc221364a8>
# BATCH_SIZE = <absl.flags._flag.Flag object at 0x7fbc22136080>
# CELL_TYPE = <absl.flags._flag.Flag object at 0x7fbc2212dcc0>
# CHECKPOINT_EVERY = <absl.flags._flag.Flag object at 0x7fbc22136320>
# DEV_SAMPLE_PERCENTAGE = <absl.flags._flag.Flag object at 0x7fbc2212db38>
# DISPLAY_EVERY = <absl.flags._flag.Flag object at 0x7fbc221361d0>
# DROPOUT_KEEP_PROB = <absl.flags._flag.Flag object at 0x7fbc2212def0>
# EMBEDDING_DIM = <absl.flags._flag.Flag object at 0x7fbc2212dda0>
# EVALUATE_EVERY = <absl.flags._flag.Flag object at 0x7fbc22136278>
# ...
